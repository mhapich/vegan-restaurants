# %% [markdown]
# # Vegan Restaurants

# %% [markdown]
# ![vegandgo.png](attachment:vegandgo.png)

# %% [markdown]
# ![onionmaiden.jpeg](attachment:onionmaiden.jpeg)

# %% [markdown]
# ![montys.png](attachment:montys.png)

# %% [markdown]
# ## Purpose

# %% [markdown]
# In this notebook, my ultimate goal is to help decision making for the opening of new vegan restaurants to optimize their success.  My hypothesis is that the level of success or failure largely comes down to these factors:
# - the population size of the city
# - accessibilty of the location from major roads
# - menu prices
# - the quality (freshness) of the menu items

# %% [markdown]
# To accomplish my goal, I will be looking at several datasets.  Some will include restaurants of all cuisines, and some will include vegetarian restaurants. The purpose here will be to take in multiple factors of a large dataset of restaurants to investigate which ones seem to be most influential in their success or failure. I will then know what to focus on when finding data on existing vegan restaurants. <br>
# The primary reason for wanting a focus before finding vegan restaurant data is that it is difficult to come by.  I will need to scrape my own dataset.  I have tried this already, [Happy Cow](https://www.happycow.net/) being the most promising site from which to gather what I need.  However, *Happy Cow* "does not want scraped". I did find code that may help me do so anyway on GitHub, but it did point out that it "may be illegal". I feel that if I can narrow down cities first where a new vegan spot could be significantly more likely to succeed, I could just gather data on restaurants from those locations. I could then use both [Happy Cow](https://www.happycow.net/) and also [Yelp](https://www.yelp.com/) to find information that I need wihout violating terms of the sites.  For [Yelp](https://www.yelp.com/) I may use their API, and for [Happy Cow](https://www.happycow.net/), I can just scrape data for certain cities without violating even their robots.txt file.

# %% [markdown]
# To get (this dataset) or not to get?  That is the question. <br>
# - [UCI Restaurant and Consumer Data](https://archive.ics.uci.edu/ml/datasets/Restaurant+%26+consumer+data#) - no; good structure and info, but from 2011
# - [Usable Databases](https://www.usabledatabases.com/database/us-restaurants/) - no; 196,673 restaurants, and is frequently updated, but it has no review information, and the only details besides location that it has is cuisine type; also, it costs $299<br><br>
# Yada yada, there were several more dead ends, from [data.gov](https://data.gov/), [Hartford Data](https://data.hartford.gov/), ...<br>
# I now remember why I keep abondoning this project.

# %% [markdown]
# I'm now feeling (🤞hoping!) [Yelp's API](https://www.yelp.com/developers/documentation/v3/get_started) to the rescue.
